# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/investments/sti_return.csv
# /kaggle/input/stock-prices/sg_stock_prices.csv

# %%
df = pd.read_csv('/kaggle/input/stock-prices/sg_stock_prices.csv')

# %%
def cleanMB(text):
    if text=='.':
        text = 0
    return float(text)
df['M/B'] = df['M/B'].apply(cleanMB)

# %%
df.head()
# Out:
#                  Company Name  GVKEY  Year  Price  Return Return (t-1)   M/B  \
# 0  GREAT EASTERN HOLDINGS LTD  15565  2006  17.00   0.156            .  2.74
# 1  GREAT EASTERN HOLDINGS LTD  15565  2007  16.60  -0.024        0.156  2.39
# 2  GREAT EASTERN HOLDINGS LTD  15565  2008   9.06  -0.454       -0.024  1.42
# 3  GREAT EASTERN HOLDINGS LTD  15565  2009  13.54   0.494       -0.454  1.80
# 4  GREAT EASTERN HOLDINGS LTD  15565  2010  15.62   0.154        0.494  1.84
#
#     Size  Score
# 0  42.03   4.42
# 1  46.52   1.95
# 2  44.03   7.08
# 3  48.53   4.16
# 4  53.37   6.23

# %%
def form_portfolios(df, n_groups=5):
    df['size_rank'] = pd.qcut(df['Size'], q=n_groups, labels=False, duplicates='drop') + 1
    df['bm_rank'] = pd.qcut(df['M/B'], q=n_groups, labels=False, duplicates='drop') + 1

    df['portfolio'] = df['size_rank'].astype(str) + 'x' + df['bm_rank'].astype(str)

    portfolio_returns = df.groupby(['Year', 'portfolio'])['Return'].mean().unstack()
    
    return portfolio_returns

portfolio_returns = form_portfolios(df)

portfolio_returns.head()
# Out:
# portfolio       1x1       1x2       1x3       1x4       1x5       2x1  \
# Year
# 2006       0.035607 -0.053389  0.196000  0.698920  0.786745  0.116889
# 2007       0.579900  0.406875  0.403933  0.805516  1.132136  0.525000
# 2008      -0.520303 -0.618824 -0.468429 -0.409182 -0.623541 -0.593452
# 2009       0.422444  0.360842  0.376905  0.407864  3.227961  0.142857
# 2010      -0.273500 -0.014917  0.052452  0.032926  0.106537  0.022100
#
# portfolio       2x2       2x3       2x4       2x5  ...       4x1       4x2  \
# Year                                               ...
# 2006       0.030474  0.130500  0.252583  0.615893  ...  0.151900  0.080000
# 2007       0.271909  0.345762  0.576848  0.689342  ...  0.286750  0.207150
# 2008      -0.444050 -0.592529 -0.475444 -0.599700  ... -0.636357 -0.567690
# 2009       0.402593  0.848167  0.774214  1.033719  ...  0.679333  0.938583
# 2010       0.077500  0.520533  0.097174  0.283187  ...  0.043565  0.110000
#
# portfolio       4x3       4x4       4x5       5x1       5x2       5x3  \
# Year
# 2006       0.441842  0.303350  0.482885  1.313833  0.463750  0.452778
# 2007       0.174741  0.256880  0.618800  0.026500 -0.034571  0.217556
# 2008      -0.487083 -0.581900 -0.477375 -0.651265 -0.596619 -0.470333
# 2009       1.023226  1.080952  0.724696  0.772937  0.902889  0.964778
# 2010       0.133133  0.133476  0.468577  0.190067  0.090889  0.057333
#
# portfolio       5x4       5x5
# Year
# 2006       0.318214  0.469000
# 2007       0.252387  0.386522
# 2008      -0.508875 -0.231375
# 2009       0.926034  0.662500
# 2010       0.142781  0.203389
#
# [5 rows x 25 columns]

# %%
def calculate_factors(df):
    # Calculate SMB (Small Minus Big)
    small = df.filter(regex='1x|2x').mean(axis=1)  # Average returns of the two smallest size quintiles
    big = df.filter(regex='4x|5x').mean(axis=1)    # Average returns of the two largest size quintiles
    smb = small - big

    # Calculate HML (High Minus Low)
    high_bm = df.filter(regex='x5').mean(axis=1)   # Average returns of the highest B/M quintile
    low_bm = df.filter(regex='x1').mean(axis=1)    # Average returns of the lowest B/M quintile
    hml = high_bm - low_bm

    return smb, hml

smb, hml = calculate_factors(portfolio_returns)

# %%
smb
# Out:
# Year
# 2006   -0.166733
# 2007    0.334451
# 2008   -0.013658
# 2009   -0.067836
# 2010   -0.066922
# 2011   -0.044865
# 2012    0.042415
# 2013    0.010752
# 2014   -0.006299
# 2015    0.003698
# 2016    0.010454
# 2017    0.002593
# 2018   -0.018944
# 2019   -0.029268
# 2020    0.085434
# 2021    0.051700
# 2022   -0.085991
# dtype: float64

# %%
market_data = pd.read_csv('/kaggle/input/investments/sti_return.csv')
market_data = market_data[market_data['Year']>=2006]

# %%
market_data.head()
# Out:
#     Year      STI  STI Return
# 6   2006  2985.83        0.27
# 7   2007  3482.30        0.17
# 8   2008  1761.56       -0.49
# 9   2009  2897.62        0.64
# 10  2010  3190.04        0.10

# %%
factors = pd.DataFrame({'smb': smb, 'hml': hml})
factors = factors.merge(market_data, left_index=True, right_on='Year', how='left')
factors['market_excess'] = factors['STI Return'] - 0

# %%
factors.head()
# Out:
#          smb       hml  Year      STI  STI Return  market_excess
# 6  -0.166733  0.221285  2006  2985.83        0.27           0.27
# 7   0.334451  0.264053  2007  3482.30        0.17           0.17
# 8  -0.013658  0.086266  2008  1761.56       -0.49          -0.49
# 9  -0.067836  0.959928  2009  2897.62        0.64           0.64
# 10 -0.066922  0.222187  2010  3190.04        0.10           0.10

# %%
factors_cleaned = factors[['Year','smb','hml','market_excess']]

# %%
factors_cleaned
# Out:
#     Year       smb       hml  market_excess
# 6   2006 -0.166733  0.221285           0.27
# 7   2007  0.334451  0.264053           0.17
# 8   2008 -0.013658  0.086266          -0.49
# 9   2009 -0.067836  0.959928           0.64
# 10  2010 -0.066922  0.222187           0.10
# 11  2011 -0.044865  0.137002          -0.17
# 12  2012  0.042415  0.630474           0.20
# 13  2013  0.010752  0.720292           0.00
# 14  2014 -0.006299 -0.068327           0.06
# 15  2015  0.003698  0.198938          -0.14
# 16  2016  0.010454  0.428754           0.00
# 17  2017  0.002593  0.524690           0.18
# 18  2018 -0.018944  0.256378          -0.10
# 19  2019 -0.029268  0.220272           0.05
# 20  2020  0.085434  0.921335          -0.12
# 21  2021  0.051700  0.441139           0.10
# 22  2022 -0.085991 -0.029075           0.04

# %%
portfolio_returns.shape
# Out:
# (17, 25)

# %%
factors.shape
# Out:
# (17, 6)

# %%
import statsmodels.api as sm
factors.reset_index(drop=True, inplace=True)


factors.index = portfolio_returns.index

def run_regressions(portfolio_returns, factors):
    results = {}
    for portfolio in portfolio_returns.columns:
        print("Hi")
        y = portfolio_returns[portfolio]  
        X = factors[['market_excess', 'smb', 'hml']]
        X = sm.add_constant(X) 
        model = sm.OLS(y, X, missing='drop').fit()
        results[portfolio] = model.params
        print(model.summary())
    return pd.DataFrame(results)

# Run regression analysis
regression_results = run_regressions(portfolio_returns, factors)
print(regression_results)
# Out:
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    1x1   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     7.465
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):            0.00373
# Time:                        10:15:17   Log-Likelihood:                 2.5761
# No. Observations:                  17   AIC:                             2.848
# Df Residuals:                      13   BIC:                             6.181
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0294      0.095     -0.311      0.761      -0.234       0.175
# market_excess     1.0563      0.284      3.726      0.003       0.444       1.669
# smb               1.6622      0.589      2.820      0.014       0.389       2.936
# hml              -0.0898      0.222     -0.404      0.693      -0.570       0.390
# ==============================================================================
# Omnibus:                        8.514   Durbin-Watson:                   2.375
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                5.462
# Skew:                           1.283   Prob(JB):                       0.0652
# Kurtosis:                       4.064   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    1x2   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     26.88
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           7.60e-06
# Time:                        10:15:17   Log-Likelihood:                 16.382
# No. Observations:                  17   AIC:                            -24.76
# Df Residuals:                      13   BIC:                            -21.43
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.1905      0.042     -4.539      0.001      -0.281      -0.100
# market_excess     0.7650      0.126      6.078      0.000       0.493       1.037
# smb               1.0700      0.262      4.089      0.001       0.505       1.635
# hml               0.1856      0.099      1.881      0.083      -0.028       0.399
# ==============================================================================
# Omnibus:                        0.482   Durbin-Watson:                   1.310
# Prob(Omnibus):                  0.786   Jarque-Bera (JB):                0.508
# Skew:                          -0.329   Prob(JB):                        0.776
# Kurtosis:                       2.467   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    1x3   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     18.17
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           6.21e-05
# Time:                        10:15:17   Log-Likelihood:                 14.811
# No. Observations:                  17   AIC:                            -21.62
# Df Residuals:                      13   BIC:                            -18.29
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0995      0.046     -2.162      0.050      -0.199   -9.45e-05
# market_excess     0.7235      0.138      5.241      0.000       0.425       1.022
# smb               0.8496      0.287      2.960      0.011       0.230       1.470
# hml               0.1588      0.108      1.467      0.166      -0.075       0.392
# ==============================================================================
# Omnibus:                        0.080   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.961   Jarque-Bera (JB):                0.144
# Skew:                          -0.113   Prob(JB):                        0.931
# Kurtosis:                       2.610   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    1x4   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     6.996
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):            0.00481
# Time:                        10:15:17   Log-Likelihood:                 4.9586
# No. Observations:                  17   AIC:                            -1.917
# Df Residuals:                      13   BIC:                             1.416
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1191      0.082      1.449      0.171      -0.058       0.297
# market_excess     0.9619      0.246      3.903      0.002       0.430       1.494
# smb               1.1956      0.512      2.334      0.036       0.089       2.303
# hml              -0.1113      0.193     -0.576      0.574      -0.529       0.306
# ==============================================================================
# Omnibus:                       11.976   Durbin-Watson:                   1.143
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                9.189
# Skew:                           1.330   Prob(JB):                       0.0101
# Kurtosis:                       5.429   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    1x5   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                     19.30
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           4.54e-05
# Time:                        10:15:17   Log-Likelihood:                -7.3201
# No. Observations:                  17   AIC:                             22.64
# Df Residuals:                      13   BIC:                             25.97
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0267      0.169     -0.158      0.877      -0.392       0.339
# market_excess     2.7116      0.507      5.343      0.000       1.615       3.808
# smb               0.8677      1.055      0.822      0.426      -1.411       3.147
# hml               0.9359      0.398      2.353      0.035       0.077       1.795
# ==============================================================================
# Omnibus:                        0.579   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.749   Jarque-Bera (JB):                0.013
# Skew:                          -0.050   Prob(JB):                        0.994
# Kurtosis:                       3.089   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    2x1   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     16.94
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           8.90e-05
# Time:                        10:15:17   Log-Likelihood:                 12.139
# No. Observations:                  17   AIC:                            -16.28
# Df Residuals:                      13   BIC:                            -12.95
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.1062      0.054     -1.972      0.070      -0.223       0.010
# market_excess     0.9462      0.162      5.858      0.000       0.597       1.295
# smb               1.2563      0.336      3.741      0.002       0.531       1.982
# hml              -0.0679      0.127     -0.537      0.601      -0.341       0.206
# ==============================================================================
# Omnibus:                        1.049   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.592   Jarque-Bera (JB):                0.691
# Skew:                           0.472   Prob(JB):                        0.708
# Kurtosis:                       2.709   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    2x2   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     21.25
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           2.73e-05
# Time:                        10:15:17   Log-Likelihood:                 16.428
# No. Observations:                  17   AIC:                            -24.86
# Df Residuals:                      13   BIC:                            -21.52
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0762      0.042     -1.820      0.092      -0.167       0.014
# market_excess     0.7690      0.126      6.127      0.000       0.498       1.040
# smb               0.7106      0.261      2.723      0.017       0.147       1.274
# hml               0.1166      0.098      1.185      0.257      -0.096       0.329
# ==============================================================================
# Omnibus:                        8.497   Durbin-Watson:                   2.623
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                5.328
# Skew:                           1.207   Prob(JB):                       0.0697
# Kurtosis:                       4.303   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    2x3   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     21.10
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           2.83e-05
# Time:                        10:15:17   Log-Likelihood:                 10.823
# No. Observations:                  17   AIC:                            -13.65
# Df Residuals:                      13   BIC:                            -10.31
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0209      0.058      0.359      0.725      -0.105       0.147
# market_excess     1.1031      0.175      6.320      0.000       0.726       1.480
# smb               0.3242      0.363      0.893      0.388      -0.460       1.108
# hml               0.1928      0.137      1.410      0.182      -0.103       0.488
# ==============================================================================
# Omnibus:                        9.484   Durbin-Watson:                   2.438
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                6.225
# Skew:                           1.238   Prob(JB):                       0.0445
# Kurtosis:                       4.630   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    2x4   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     6.921
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):            0.00501
# Time:                        10:15:17   Log-Likelihood:              -0.043641
# No. Observations:                  17   AIC:                             8.087
# Df Residuals:                      13   BIC:                             11.42
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0627      0.110     -0.568      0.579      -0.301       0.176
# market_excess     0.5704      0.331      1.725      0.108      -0.144       1.285
# smb               1.0858      0.688      1.579      0.138      -0.400       2.571
# hml               0.6602      0.259      2.547      0.024       0.100       1.220
# ==============================================================================
# Omnibus:                        9.298   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                6.044
# Skew:                           1.236   Prob(JB):                       0.0487
# Kurtosis:                       4.557   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    2x5   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     12.01
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           0.000476
# Time:                        10:15:17   Log-Likelihood:                -3.3229
# No. Observations:                  17   AIC:                             14.65
# Df Residuals:                      13   BIC:                             17.98
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0673      0.134     -0.503      0.623      -0.356       0.222
# market_excess     0.9236      0.401      2.303      0.038       0.057       1.790
# smb               1.0787      0.834      1.293      0.218      -0.723       2.880
# hml               1.1400      0.314      3.626      0.003       0.461       1.819
# ==============================================================================
# Omnibus:                        0.345   Durbin-Watson:                   2.441
# Prob(Omnibus):                  0.841   Jarque-Bera (JB):                0.423
# Skew:                           0.276   Prob(JB):                        0.809
# Kurtosis:                       2.459   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    3x1   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     17.10
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           8.47e-05
# Time:                        10:15:17   Log-Likelihood:                 13.039
# No. Observations:                  17   AIC:                            -18.08
# Df Residuals:                      13   BIC:                            -14.74
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0762      0.051     -1.492      0.160      -0.187       0.034
# market_excess     0.9263      0.153      6.046      0.000       0.595       1.257
# smb               0.7927      0.319      2.489      0.027       0.105       1.481
# hml               0.0147      0.120      0.122      0.905      -0.245       0.274
# ==============================================================================
# Omnibus:                        1.214   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.545   Jarque-Bera (JB):                0.911
# Skew:                           0.528   Prob(JB):                        0.634
# Kurtosis:                       2.589   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    3x2   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     15.17
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           0.000155
# Time:                        10:15:17   Log-Likelihood:                 12.204
# No. Observations:                  17   AIC:                            -16.41
# Df Residuals:                      13   BIC:                            -13.07
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0791      0.054     -1.475      0.164      -0.195       0.037
# market_excess     0.8398      0.161      5.218      0.000       0.492       1.187
# smb              -0.2783      0.335     -0.832      0.421      -1.001       0.445
# hml               0.1709      0.126      1.355      0.199      -0.102       0.443
# ==============================================================================
# Omnibus:                        4.389   Durbin-Watson:                   1.698
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                2.522
# Skew:                           0.931   Prob(JB):                        0.283
# Kurtosis:                       3.311   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    3x3   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     44.49
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           4.26e-07
# Time:                        10:15:17   Log-Likelihood:                 12.891
# No. Observations:                  17   AIC:                            -17.78
# Df Residuals:                      13   BIC:                            -14.45
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0428      0.052     -0.830      0.421      -0.154       0.069
# market_excess     1.4035      0.155      9.081      0.000       1.070       1.737
# smb               0.1264      0.321      0.393      0.700      -0.568       0.821
# hml               0.2745      0.121      2.266      0.041       0.013       0.536
# ==============================================================================
# Omnibus:                        1.098   Durbin-Watson:                   1.399
# Prob(Omnibus):                  0.578   Jarque-Bera (JB):                0.844
# Skew:                           0.502   Prob(JB):                        0.656
# Kurtosis:                       2.573   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    3x4   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     24.96
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           1.14e-05
# Time:                        10:15:17   Log-Likelihood:                 12.044
# No. Observations:                  17   AIC:                            -16.09
# Df Residuals:                      13   BIC:                            -12.76
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0449      0.054      0.829      0.422      -0.072       0.162
# market_excess     0.9534      0.162      5.869      0.000       0.603       1.304
# smb               0.5625      0.338      1.666      0.120      -0.167       1.292
# hml               0.3552      0.127      2.790      0.015       0.080       0.630
# ==============================================================================
# Omnibus:                        0.985   Durbin-Watson:                   1.202
# Prob(Omnibus):                  0.611   Jarque-Bera (JB):                0.358
# Skew:                           0.355   Prob(JB):                        0.836
# Kurtosis:                       3.001   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    3x5   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     4.670
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):             0.0200
# Time:                        10:15:17   Log-Likelihood:                -12.810
# No. Observations:                  17   AIC:                             33.62
# Df Residuals:                      13   BIC:                             36.95
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.1510      0.234     -0.646      0.529      -0.656       0.354
# market_excess     1.0224      0.701      1.459      0.168      -0.492       2.537
# smb              -0.4823      1.457     -0.331      0.746      -3.630       2.666
# hml               1.3272      0.549      2.416      0.031       0.140       2.514
# ==============================================================================
# Omnibus:                       28.246   Durbin-Watson:                   2.304
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.982
# Skew:                           2.415   Prob(JB):                     6.28e-11
# Kurtosis:                       9.558   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    4x1   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     10.91
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           0.000741
# Time:                        10:15:17   Log-Likelihood:                 4.0790
# No. Observations:                  17   AIC:                           -0.1579
# Df Residuals:                      13   BIC:                             3.175
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.1217      0.087     -1.406      0.183      -0.309       0.065
# market_excess     1.2140      0.260      4.678      0.000       0.653       1.775
# smb               0.5001      0.540      0.927      0.371      -0.666       1.666
# hml               0.1526      0.203      0.750      0.466      -0.287       0.592
# ==============================================================================
# Omnibus:                       18.434   Durbin-Watson:                   1.705
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.173
# Skew:                           1.886   Prob(JB):                     0.000113
# Kurtosis:                       6.380   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    4x2   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     61.15
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           6.38e-08
# Time:                        10:15:17   Log-Likelihood:                 19.906
# No. Observations:                  17   AIC:                            -31.81
# Df Residuals:                      13   BIC:                            -28.48
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0892      0.034     -2.616      0.021      -0.163      -0.016
# market_excess     1.1010      0.102     10.763      0.000       0.880       1.322
# smb               0.1672      0.213      0.786      0.446      -0.292       0.627
# hml               0.1973      0.080      2.461      0.029       0.024       0.371
# ==============================================================================
# Omnibus:                        0.465   Durbin-Watson:                   1.155
# Prob(Omnibus):                  0.793   Jarque-Bera (JB):                0.352
# Skew:                          -0.308   Prob(JB):                        0.839
# Kurtosis:                       2.656   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    4x3   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     66.12
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           3.97e-08
# Time:                        10:15:17   Log-Likelihood:                 19.411
# No. Observations:                  17   AIC:                            -30.82
# Df Residuals:                      13   BIC:                            -27.49
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0427      0.035     -1.216      0.246      -0.119       0.033
# market_excess     1.1944      0.105     11.341      0.000       0.967       1.422
# smb              -0.2449      0.219     -1.119      0.284      -0.718       0.228
# hml               0.1810      0.083      2.193      0.047       0.003       0.359
# ==============================================================================
# Omnibus:                        2.098   Durbin-Watson:                   1.314
# Prob(Omnibus):                  0.350   Jarque-Bera (JB):                1.025
# Skew:                           0.114   Prob(JB):                        0.599
# Kurtosis:                       1.819   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    4x4   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     49.34
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           2.31e-07
# Time:                        10:15:17   Log-Likelihood:                 15.274
# No. Observations:                  17   AIC:                            -22.55
# Df Residuals:                      13   BIC:                            -19.21
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0069      0.045      0.153      0.880      -0.090       0.104
# market_excess     1.2821      0.134      9.544      0.000       0.992       1.572
# smb               0.2165      0.279      0.775      0.452      -0.387       0.820
# hml               0.2531      0.105      2.404      0.032       0.026       0.481
# ==============================================================================
# Omnibus:                        4.192   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.123   Jarque-Bera (JB):                2.195
# Skew:                           0.848   Prob(JB):                        0.334
# Kurtosis:                       3.476   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    4x5   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     4.591
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):             0.0211
# Time:                        10:15:17   Log-Likelihood:                -13.335
# No. Observations:                  17   AIC:                             34.67
# Df Residuals:                      13   BIC:                             38.00
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.2378      0.241     -0.987      0.342      -0.758       0.283
# market_excess    -0.0482      0.723     -0.067      0.948      -1.610       1.513
# smb               1.3217      1.503      0.879      0.395      -1.925       4.568
# hml               1.7358      0.567      3.064      0.009       0.512       2.960
# ==============================================================================
# Omnibus:                        4.280   Durbin-Watson:                   2.439
# Prob(Omnibus):                  0.118   Jarque-Bera (JB):                1.989
# Skew:                           0.716   Prob(JB):                        0.370
# Kurtosis:                       3.868   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    5x1   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     10.63
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           0.000835
# Time:                        10:15:17   Log-Likelihood:                0.76776
# No. Observations:                  17   AIC:                             6.464
# Df Residuals:                      13   BIC:                             9.797
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0333      0.105     -0.317      0.756      -0.260       0.194
# market_excess     1.3864      0.315      4.397      0.001       0.705       2.068
# smb              -1.2325      0.656     -1.880      0.083      -2.649       0.184
# hml               0.1286      0.247      0.520      0.612      -0.405       0.663
# ==============================================================================
# Omnibus:                       17.270   Durbin-Watson:                   1.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.968
# Skew:                           1.719   Prob(JB):                     0.000207
# Kurtosis:                       6.483   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    5x2   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     56.89
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           9.85e-08
# Time:                        10:15:17   Log-Likelihood:                 17.650
# No. Observations:                  17   AIC:                            -27.30
# Df Residuals:                      13   BIC:                            -23.97
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.1177      0.039     -3.021      0.010      -0.202      -0.034
# market_excess     1.1461      0.117      9.811      0.000       0.894       1.398
# smb              -0.6119      0.243     -2.519      0.026      -1.137      -0.087
# hml               0.2611      0.092      2.852      0.014       0.063       0.459
# ==============================================================================
# Omnibus:                        0.017   Durbin-Watson:                   1.558
# Prob(Omnibus):                  0.991   Jarque-Bera (JB):                0.145
# Skew:                           0.051   Prob(JB):                        0.930
# Kurtosis:                       2.559   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    5x3   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     88.97
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           6.44e-09
# Time:                        10:15:17   Log-Likelihood:                 22.364
# No. Observations:                  17   AIC:                            -36.73
# Df Residuals:                      13   BIC:                            -33.40
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0149      0.030      0.505      0.622      -0.049       0.079
# market_excess     1.2596      0.089     14.229      0.000       1.068       1.451
# smb              -0.1811      0.184     -0.984      0.343      -0.579       0.217
# hml               0.0357      0.069      0.514      0.616      -0.114       0.186
# ==============================================================================
# Omnibus:                        0.067   Durbin-Watson:                   1.487
# Prob(Omnibus):                  0.967   Jarque-Bera (JB):                0.287
# Skew:                           0.068   Prob(JB):                        0.866
# Kurtosis:                       2.378   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    5x4   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     72.75
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           2.22e-08
# Time:                        10:15:17   Log-Likelihood:                 21.958
# No. Observations:                  17   AIC:                            -35.92
# Df Residuals:                      13   BIC:                            -32.58
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0138      0.030     -0.457      0.655      -0.079       0.051
# market_excess     1.0755      0.091     11.863      0.000       0.880       1.271
# smb              -0.0275      0.188     -0.146      0.886      -0.435       0.380
# hml               0.1762      0.071      2.480      0.028       0.023       0.330
# ==============================================================================
# Omnibus:                        1.890   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.389   Jarque-Bera (JB):                1.229
# Skew:                          -0.648   Prob(JB):                        0.541
# Kurtosis:                       2.759   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hi
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    5x5   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     22.78
# Date:                Tue, 16 Apr 2024   Prob (F-statistic):           1.88e-05
# Time:                        10:15:17   Log-Likelihood:                 16.535
# No. Observations:                  17   AIC:                            -25.07
# Df Residuals:                      13   BIC:                            -21.74
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1159      0.042      2.787      0.015       0.026       0.206
# market_excess     0.9199      0.125      7.375      0.000       0.650       1.189
# smb               0.1931      0.259      0.745      0.470      -0.367       0.753
# hml              -0.0007      0.098     -0.007      0.995      -0.212       0.211
# ==============================================================================
# Omnibus:                        0.965   Durbin-Watson:                   1.090
# Prob(Omnibus):                  0.617   Jarque-Bera (JB):                0.722
# Skew:                          -0.057   Prob(JB):                        0.697
# Kurtosis:                       1.997   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                     1x1       1x2       1x3       1x4       1x5       2x1  \
# const         -0.029416 -0.190482 -0.099527  0.119059 -0.026688 -0.106221
# market_excess  1.056340  0.765035  0.723490  0.961909  2.711570  0.946230
# smb            1.662196  1.069970  0.849633  1.195644  0.867727  1.256296
# hml           -0.089796  0.185565  0.158751 -0.111349  0.935892 -0.067947
#
#                     2x2       2x3       2x4       2x5  ...       4x1  \
# const         -0.076151  0.020888 -0.062690 -0.067281  ... -0.121678
# market_excess  0.769014  1.103081  0.570437  0.923638  ...  1.214024
# smb            0.710613  0.324206  1.085800  1.078657  ...  0.500109
# hml            0.116601  0.192836  0.660222  1.139984  ...  0.152639
#
#                     4x2       4x3       4x4       4x5       5x1       5x2  \
# const         -0.089212 -0.042684  0.006872 -0.237798 -0.033338 -0.117663
# market_excess  1.100978  1.194372  1.282094 -0.048217  1.386433  1.146080
# smb            0.167193 -0.244927  0.216487  1.321678 -1.232482 -0.611866
# hml            0.197297  0.181034  0.253083  1.735753  0.128605  0.261148
#
#                     5x3       5x4       5x5
# const          0.014910 -0.013806  0.115886
# market_excess  1.259575  1.075487  0.919919
# smb           -0.181064 -0.027483  0.193097
# hml            0.035656  0.176194 -0.000652
#
# [4 rows x 25 columns]

# %%
regression_results
# Out:
#                     1x1       1x2       1x3       1x4       1x5       2x1  \
# const         -0.029416 -0.190482 -0.099527  0.119059 -0.026688 -0.106221
# market_excess  1.056340  0.765035  0.723490  0.961909  2.711570  0.946230
# smb            1.662196  1.069970  0.849633  1.195644  0.867727  1.256296
# hml           -0.089796  0.185565  0.158751 -0.111349  0.935892 -0.067947
#
#                     2x2       2x3       2x4       2x5  ...       4x1  \
# const         -0.076151  0.020888 -0.062690 -0.067281  ... -0.121678
# market_excess  0.769014  1.103081  0.570437  0.923638  ...  1.214024
# smb            0.710613  0.324206  1.085800  1.078657  ...  0.500109
# hml            0.116601  0.192836  0.660222  1.139984  ...  0.152639
#
#                     4x2       4x3       4x4       4x5       5x1       5x2  \
# const         -0.089212 -0.042684  0.006872 -0.237798 -0.033338 -0.117663
# market_excess  1.100978  1.194372  1.282094 -0.048217  1.386433  1.146080
# smb            0.167193 -0.244927  0.216487  1.321678 -1.232482 -0.611866
# hml            0.197297  0.181034  0.253083  1.735753  0.128605  0.261148
#
#                     5x3       5x4       5x5
# const          0.014910 -0.013806  0.115886
# market_excess  1.259575  1.075487  0.919919
# smb           -0.181064 -0.027483  0.193097
# hml            0.035656  0.176194 -0.000652
#
# [4 rows x 25 columns]

# %%
regression_results.to_csv('result.csv')

# %%
portfolio_returns.to_csv('portfolio_formation-1.5.csv')

# %%
factors_cleaned.to_csv('ffm_factors-1.5.csv')
